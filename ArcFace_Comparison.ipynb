# %%
pip install deepface

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
img1_path = "barack2.jpg"
img2_path = "bill2.jpg"

# %%
img1 = DeepFace.detectFace(img1_path)
img2 = DeepFace.detectFace(img2_path)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
detector_backend = "mtcnn"

# %%
model_name = "OpenFace"

# %%
resp = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name = model_name, detector_backend = detector_backend)
# Out:
# openface_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5
# To: /root/.deepface/weights/openface_weights.h5
# 100%|██████████| 15.3M/15.3M [00:01<00:00, 11.8MB/s]
# ...
# 1/1 [==============================] - 0s 27ms/step

# %%
resp
# Out:
# {'verified': False,
#  'distance': 0.2138904695656586,
#  'threshold': 0.1,
#  'model': 'OpenFace',
#  'detector_backend': 'mtcnn',
#  'similarity_metric': 'cosine'}
